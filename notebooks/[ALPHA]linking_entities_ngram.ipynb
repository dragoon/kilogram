# %% [markdown]
# <small><i>This notebook was put together by [Roman Prokofyev](http://prokofyev.ch)@[eXascale Infolab](http://exascale.info/). Source and license info is on [GitHub](https://github.com/dragoon/kilogram/).</i></small>

# %% [markdown]
# # Prerequisites
#
# * Pandas: ``pip install pandas``
# * Matplotlib

# %% [markdown]
# # Linking DBPedia entity types in N-gram corpus
# In this sub-tutorial, we will link DBPedia entities (and subsequently types) in an N-gram corpus. In our case, we used n-grams generated out of **Wikipedia pages**, to compare if our linking is better than original.
#
# Clone **kilogram** library if you haven't done it yet:
#
#     git clone https://github.com/dragoon/kilogram.git
#     cd kilogram/mapreduce
#
# Download required **DBPedia** datasets:
#
#     wget http://downloads.dbpedia.org/3.9/en/redirects_transitive_en.nt.bz2
#     wget http://downloads.dbpedia.org/3.9/en/instance_types_en.nt.bz2

# %%
import matplotlib.pyplot as plt
from mpltools import style
import numpy as np
style.use('ggplot')
# %matplotlib inline
import pandas as pd
import shelve
from collections import defaultdict

# %% [markdown]
# # Organic (human) linkings
# Since we want to prove we link entity types better than original (human) annonators, we need to first extract original linkings for comparison.

# %% [markdown]
# # Analysis: raw counts
#
# First we try to see what happens if we perform stupid linking by means of exact string matching, using canonical and "redirect" labels of wikipedia pages. All such labels uniquely link to a single entity (ensured by wikipedia, we don't check it here).
#
# We aggregate the counts of the labels and also of their lowercase versions for further analysis.
# Initially the script will also generate DBPedia entity dictionary which maps labels to entity types (used later):
#
#     ./run_job.py -cmd "python dbpedia_dbm.py" -file dbpedia_types.dbm dbpedia_lowercase2labels.dbm -m ./filter/mapper_lowercase.py -r ./filter/reducer_lowercase.py $NGRAM_PREFILTER_DIR $DBPEDIA_COUNT_DIR
#
# Retrieve label counts:
#
#     hdfs dfs -cat $DBPEDIA_COUNT_DIR/* > dbpedia_counts_inferred

# %% [markdown]
# # Construct original counts file

# %%
anchorsdb = shelve.open('../mapreduce/dbpedia_anchors.dbm', flag='r')
dbpediadb = shelve.open('../mapreduce/dbpedia_types.dbm', flag='r')
dbpediadb_lower = {}
for key in dbpediadb.iterkeys():
    dbpediadb_lower[key.lower()] = key

# no need to process whole wikipedia, anchors dict with counts is enough
orig_ratio = open('../mapreduce/dbpedia_counts_original', 'w')
for values in anchorsdb.itervalues():
    counts = defaultdict(lambda: {'upper': 0, 'lower': 0})
    for anchor, count in values.items():
        uri_anchor = anchor.replace(' ', '_')
        if uri_anchor in dbpediadb:
            counts[uri_anchor]['upper'] = int(count)
        elif uri_anchor in dbpediadb_lower:
            counts[dbpediadb_lower[uri_anchor]]['lower'] = int(count)

    for key, c in counts.items():
        orig_ratio.write("%s\t%d,%d\n" % (key, c['upper'], c['lower']))
orig_ratio.close()
anchorsdb.close()
dbpediadb.close()
del dbpediadb_lower

# %%
#dbpedia_types = shelve.open('../mapreduce/PARAM_plus_achors/dbpedia_types.dbm', flag='r')
dbpedia_types = shelve.open('../mapreduce/dbpedia_types.dbm', flag='r')
count_dict = {}
for line in open('dbpedia_counts_inferred'):
    label, values = line.split('\t')
    upper_count, lower_count = values.split(',')
    count_dict[label] = {'infer_upper': int(upper_count), 'infer_lower': int(lower_count), 'len': len(label.split('_')),
                       'label': label, 'organ_upper': 0, 'organ_lower': 0, 'type': dbpedia_types[label][0],
                       'istitle': label.istitle()}
for line in open('dbpedia_counts_original'):
    label, values = line.split('\t')
    if label in count_dict:
        upper_count, lower_count = values.split(',')
        count_dict[label].update({'organ_upper': int(upper_count), 'organ_lower': int(lower_count)})
counts_df = pd.DataFrame(count_dict.values())
counts_df.head()
del count_dict

# %%
a = set(counts_df[(counts_df.infer_upper + counts_df.infer_lower > 0)]['type'])
b = set(counts_df[(counts_df.organ_upper + counts_df.organ_lower > 0)]['type'])
print 'Total number of inferred types:',  len(a)
print 'Total number of original types:',  len(b)
print a.difference(b)
# Out:
# Total number of inferred types: 339
# Total number of original types: 338
# set(['SnookerWorldRanking'])

# %% [markdown]
# ## Inferred vs Organic counts of original-case labels
# ### Unigrams

# %%
ax = counts_df[(counts_df.len==1) & (counts_df.istitle==1)].plot(kind='scatter',x='organ_upper', y='infer_upper', figsize=(9,5), xlim=(0,1000), ylim=(0,1000))
ax.set_xlabel("User-curated count", size='x-large')
ax.set_ylabel("Inferred count", size='x-large')
fig = ax.get_figure()
fig.savefig('/home/roman/unigram_counts.pdf')

# %% [markdown]
# ### Bigrams

# %%
ax = counts_df[(counts_df.len>1) & (counts_df.istitle==1)].plot(kind='scatter',x='organ_upper', y='infer_upper', figsize=(9,5), xlim=(0,1000), ylim=(0,1000))
ax.set_xlabel("User-curated count", size='x-large')
ax.set_ylabel("Inferred count", size='x-large')
fig = ax.get_figure()
fig.savefig('/home/roman/ngram_counts.pdf')

# %% [markdown]
# # Some corner cases

# %%
counts_df[(counts_df.new_upper==0) & (counts_df.orig_upper==0)][:10]
# Out:
#                            label  new_lower  new_upper  orig_lower  \
# 2         Unadorned_rock-wallaby          1          0           3
# 29   Guerra_de_la_Triple_Alianza          1          0           0
# 80         Member_of_the_wedding          4          0           0
# 122     Naked-rumped_Pouched_Bat          1          0           0
# 169                 Stink_badger         15          0           0
# 200       Central_lymphoid_organ          1          0           0
# 251    Grey-crested_Helmetshrike          1          0           0
# 254     Someone_To_Share_It_With          2          0           0
# 287            Year_of_the_horse          5          0           0
# 291    Where_the_wild_things_are          1          0           0
#
#      orig_upper                 type
# 2             0               Mammal
# 29            0     MilitaryConflict
# 80            0                 Book
# 122           0               Mammal
# 169           0               Mammal
# ...

# %% [markdown]
# **We never exclude the above entities - can only appear in lower case**

# %%
counts_df[(counts_df.infer_upper>1000) & (counts_df.organ_upper==0) & (counts_df.len>1) & (counts_df.istitle==1)][:10]
# Out:
#         infer_lower  infer_upper istitle                     label  len  \
# 8213             14         1544    True  National_Weather_Service    3
# 24126             0         1149    True       American_Federation    2
# 60667            63         2625    True         Protection_Agency    2
# 98925            10         4146    True                 The_Dutch    2
# 203970            8         1141    True          National_Olympic    2
# 238857           39         1083    True             Common_Prayer    2
# 266174         5292        37807    True           Football_League    2
# 315385            0         3751    True         Atlanta_,_Georgia    3
# 386642            0         3840    True                   John_C.    2
# 408801         8933         1787    True                    If_You    2
#
#         organ_lower  organ_upper              type
# 8213              2            0  GovernmentAgency
# 24126             0            0           Country
# ...

# %% [markdown]
# Perhaps these cases should be filtered by new_upper/new_lower ratio

# %%
counts_df[(counts_df.new_lower>1000) & (counts_df.orig_lower==0) & (counts_df.orig_upper>0)][:10]
# Out:
#                label  new_lower  new_upper  orig_lower  orig_upper     type
# 883          Couples      60981        618           0           1     Book
# 2249          Thrice       1279        170           0           2     Band
# 2788  Commit_Suicide       3110          6           0           1  Disease
# 3843       The_Cabin       3077         97           0           2     Film
# 5504            Ford       2239      42438           0           3  Company
# 6317    On_The_Level       1210          9           0           1    Album
# 6760           STRAP       2033          5           0           2  Protein
# 7840      The_Ladder       1784        178           0          12    Album
# 8503           MINDS       7525         45           0           1  Company
# 9223        Pristine       1857         78           0           1     City

# %%
counts_df[(counts_df.new_lower>1000) & (counts_df.new_upper>1000)][:10]
# Out:
#               label  new_lower  new_upper  orig_lower  orig_upper  \
# 32             Euro       4138       5293           1           3
# 5504           Ford       2239      42438           0           3
# 10035         Black     148505     118705           3           0
# 12627     The_rules      12445       2141           0           0
# 12932  The_Guardian       1045       7953           0        7485
# 14509      Chestnut       3095       2752           1           0
# 14926      The_bill      13663       6132           0           0
# 23560         Brown      43721      68189           0           2
# 24235          Most     977390     147258           0         106
# 27502         Tours      20627       4755           0           3
#
#                  type
# 32           Currency
# 5504          Company
# 10035          Colour
# 12627            Book
# 12932       Newspaper
# 14509           Plant
# 14926  TelevisionShow
# 23560          Colour
# 24235      Settlement
# ...

# %% [markdown]
# ## Inferred vs Organic capitalized/lowercase ratio plots

# %%
def ratio(row):
    new_ratio = row['infer_upper']/float(row['infer_lower'] or 1)
    orig_ratio = row['organ_upper']/float(row['organ_lower'] or 1)
    return pd.Series({'new_ratio': new_ratio, 'orig_ratio': orig_ratio, 'type': row['type']})

ratio_df = counts_df.apply(ratio, axis=1)
print ratio_df.head()

# %%
ax=ratio_df[(ratio_df.type=='Settlement')].plot(title='Settlement type',kind='scatter',x='orig_ratio', y='new_ratio', figsize=(18,10), xlim=(0,500), ylim=(0,500))
ax=ratio_df[(ratio_df.type=='Person')].plot(title='Person type',kind='scatter',x='orig_ratio', y='new_ratio', figsize=(18,10), xlim=(0,500), ylim=(0,500))

# %%
ax=ratio_df.plot(kind='scatter',x='orig_ratio', y='new_ratio', figsize=(18,10), xlim=(0,1000), ylim=(0,1000))
x = np.arange(0, 1000, 0.1);
plt.plot(x, x, axes=ax, scaley=False, scalex=False)

# %%
from math import log
ratio_df[(ratio_df.orig_ratio<1000) & (ratio_df.new_ratio<1000)].plot(kind='hexbin', x='orig_ratio', y='new_ratio', figsize=(18,10), gridsize=50, C=1, reduce_C_function=lambda x: log(sum(x)))

# %%
# Write excludes file, create lowercase mathings file
dbpediadb_lower = {}
#excludes = open('../mapreduce/PARAM_plus_achors/dbpedia_uri_excludes.txt', 'w')
excludes = open('dbpedia_uri_excludes.txt', 'w')
for row in counts_df.iterrows():
    row = row[1]
    exclude = False
    label = row['label']
    
    # skip uppercase
    if label.isupper():
        continue
    # skip titlecased labels than are bigrams and higher
    if label.count('_') > 0 and label.istitle():
        # add to lower db
        if row['organ_lower'] > 0:
            dbpediadb_lower[label.lower()] = label
        continue
    if row['organ_upper'] == 0:
        if row['infer_upper'] == 0:
            pass
        else:
            new_ratio = row['infer_upper']/float(row['infer_lower'] or 1)
            if new_ratio < 20:
                exclude = True
    else:
        new_ratio = row['infer_upper']/float(row['infer_lower'] or 1)
        orig_ratio = row['organ_upper']/float(row['organ_lower'] or 1)
        if new_ratio < orig_ratio:
            exclude = True
    if exclude:
        excludes.write(label+'\n')
    elif row['organ_lower'] > 0:
        dbpediadb_lower[label.lower()] = label
excludes.close()

# %%
#out = open('../mapreduce/PARAM_plus_achors/dbpediadb_lower.txt', 'w')
out = open('dbpediadb_lower.txt', 'w')
for lower_label, label in dbpediadb_lower.items():
    out.write('%s\t%s\n' % (lower_label, label))
out.close()

# %% [markdown]
# # Finding sparse types

# %%
from collections import defaultdict
type_counts = defaultdict(lambda: [0,0])
for i, vocab in enumerate((open('dbpedia_org_types_1gms'), open('dbpedia_infer_types_1gms'))):
    for line in vocab:
        word, count = line.split('\t')
        type_counts[word][i] = int(count)
df = pd.DataFrame([(k,v[0],v[1]) for k,v in type_counts.items()], columns=['type', 'orig_types', 'inferred_types'])

# %%
import numpy as np
q75, q25 = np.percentile(df['orig_types'], [75 ,25])
print q25
print df[(df.inferred_types<q25)]['type'].tolist()
open('sparse_types.txt', 'w').write('\n'.join(df[(df.inferred_types<q25)]['type'].tolist()))
# Out:
# 1886.75
# ...

# %% [markdown]
# # Anchor dict analysis

# %%
anchorsdb = shelve.open('../mapreduce/dbpedia_anchors.dbm', flag='r')
dbpediadb = shelve.open('../mapreduce/dbpedia_types.dbm', flag='r')

print 'Anchors DB len:', sum(len(x) for x in anchorsdb.itervalues())
ambig_db = {}
all_labels = set(dbpediadb.keys())
for key, values in anchorsdb.iteritems():
    values = set([x.replace(' ', '_') for x in values]).difference(all_labels)
    if values:
        ambig_db[key] = values
print 'Len of anchors minus canon/redirects', sum(len(x) for x in ambig_db.itervalues())
del all_labels
# Out:
# Anchors DB len:
# 3291965
# Len of anchors minus canon/redirects
#  1424607

# %%
# remove ambiguous labels
import subprocess
import urllib
ambiguous_labels = set()
# BZ2File module cannot process multi-stream files, so use subprocess
p = subprocess.Popen('bzcat -q ../mapreduce/disambiguations_en.nt.bz2', shell=True, stdout=subprocess.PIPE)
for line in p.stdout:
    if '<BAD URI: Illegal character' in line:
        continue
    try:
        uri, predicate, type_uri = line.split(' ', 2)
    except:
        continue
    label = urllib.unquote(uri.replace('<http://dbpedia.org/resource/', '')[:-1]).replace('_(disambiguation)', '')
    ambiguous_labels.add(label)
print 'Ambiguous labels len:', len(ambiguous_labels)
# Out:
# Ambiguous labels len: 216552

# %%
for key, values in ambig_db.iteritems():
    ambig_db[key] = values.difference(ambiguous_labels)
print 'Len of anchors minus ambiguous labels minus canon/redirects:', sum(len(x) for x in ambig_db.itervalues())
# Out:
# Len of anchors minus ambiguous labels minus canon/redirects
# 1090689

# %%
# remove duplicate labels
duplicates = defaultdict(lambda: 0)
for values in ambig_db.itervalues():
    for value in values:
        duplicates[value] += 1
duplicates = set([k for k,v in duplicates.iteritems() if v>1])
print 'Total duplicates:', len(duplicates)
for key, values in ambig_db.iteritems():
    ambig_db[key] = values.difference(duplicates)
print 'Len of anchors minus duplicates:', sum(len(x) for x in ambig_db.itervalues())
# Out:
# Total duplicates: 93905
# Len of anchors minus duplicates:
#  763045

# %%
clean_anchors = shelve.open('../mapreduce/clean_anchors_types.dbm')
for canon_uri, labels in ambig_db.iteritems():
    for label in labels:
        clean_anchors[label] = dbpediadb[canon_uri]
clean_anchors.close()
anchorsdb.close()
dbpediadb.close()

# %% [markdown]
# # Statistical significance test

# %%
from scipy.stats import ttest_rel
with open('/home/roman/berkeleylm/temp.log') as a:
    simple_data = [float(x.split(';')[0]) for x in a]
with open('/home/roman/berkeleylm/temp1.log') as a:
    generic_data = [float(x.split(';')[0]) for x in a]
del generic_data[-1]
del simple_data[-1]

#print 'T-test merged vs orig:', ttest_rel(merged_wiki_data, orig_wiki_data)
#print 'T-test merged vs custom:', ttest_rel(merged_wiki_data, custom_wiki_data)
print 'T-test custom vs orig:', ttest_rel(generic_data, simple_data)
# Out:
# T-test custom vs orig: (664.539616654572, 0.0)

# %%
diff = [(x-y) for x,y in zip(generic_data,simple_data)]
from collections import defaultdict
import pandas as pd
type_scores = defaultdict(list)
with open('/home/roman/berkeleylm/wiki_test_generic_1t.txt') as input:
    for i, sentence in enumerate(input):
        local_types = set([x for x in sentence.split() if x.startswith('<dbpedia:')])
        if len(local_types) == 1:
            type_scores[list(local_types)[0]].append(diff[i])

# %%
type_scores_mean = [(x,np.mean(y)) for x,y in type_scores.items()]
type_scores_mean.sort(key=lambda x: x[1])
type_scores_mean
# Out:
# [('<dbpedia:YearInSpaceflight>', -17.022187000000002),
#  ('<dbpedia:SportCompetitionResult>', 0.7394566556291392),
#  ('<dbpedia:Colour>', 2.6474185767575324),
#  ('<dbpedia:Activity>', 3.7261851366548577),
#  ('<dbpedia:Database>', 4.9947402690583003),
#  ('<dbpedia:CelestialBody>', 5.522405373862159),
#  ('<dbpedia:Language>', 7.2859266787890631),
#  ('<dbpedia:Holiday>', 7.4133124481855592),
#  ('<dbpedia:EthnicGroup>', 7.4970548963435215),
#  ('<dbpedia:SportsSeason>', 8.1953358243626067),
#  ('<dbpedia:Name>', 8.3240338561643838),
#  ('<dbpedia:AnatomicalStructure>', 8.4320825813901337),
#  ('<dbpedia:TopicalConcept>', 8.6453756998100069),
#  ('<dbpedia:Disease>', 9.4566526421712673),
#  ('<dbpedia:Award>', 10.17681669824923),
#  ('<dbpedia:SnookerWorldRanking>', 11.624078600000001),
#  ('<dbpedia:Food>', 11.752175568726358),
#  ('<dbpedia:ChemicalSubstance>', 11.986583436422666),
#  ('<dbpedia:Event>', 12.104437352305004),
#  ('<dbpedia:Species>', 12.429313632737133),
# ...

# %%
diff = [(x-y) for x,y in zip(generic_data,specific_data)]
df = pd.DataFrame(diff)
df.hist(bins=100, figsize=(18,10))
print df.mean()
print df.std()
# Out:
# 0   -25.370337
# dtype: float64
# 0    168.282312
# dtype: float64

# %%
diff_index = list(enumerate(diff))

# %%
diff_index = sorted(diff_index, key=lambda x: x[1], reverse=True)

# %%
print diff_index[:10]
print diff_index[-10:]
# Out:
# [(182928, 4228.245728), (95989, 3242.797912), (122553, 2554.877533), (172474, 2300.813247), (157932, 2062.490052), (142978, 1718.108948), (156539, 1638.072052), (40053, 1602.8664250000002), (91078, 1588.267075), (35241, 1557.570831)]
# [(110920, -1724.910316), (25679, -1783.9314570000001), (17989, -1895.977722), (1429, -1920.229981), (148831, -1948.588776), (63523, -2020.874878), (98127, -2033.699646), (38684, -2417.673095), (38588, -3298.812774), (86409, -3899.1409610000005)]

# %% [markdown]
# Run a job to generate typed n-grams for non-excluded entities: (we have also added the "excludes file" to the repo):
#
#     ./run_job.py -file "dbpedia_types.dbm" "../extra/dbpedia_uri_excludes.txt" "../extra/dbpediadb_lower.txt" -m ./filter/mapper_dbpedia.py $NGRAM_PREFILTER_DIR $DBPEDIA_TYPE_DIR
#
# Then move typed n-grams back to $NGRAM_PREFILTER_DIR (with different names, we move it to save time instead of running a merge job):
#
#     ./move_plain.sh
