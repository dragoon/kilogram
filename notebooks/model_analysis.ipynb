# %% [markdown]
# <small><i>This notebook was put together by [Roman Prokofyev](http://prokofyev.ch)@[eXascale Infolab](http://exascale.info/). Source and license info is on [GitHub](https://github.com/dragoon/kilogram/).</i></small>

# %% [markdown]
# # Prerequisites
#
# * Pandas: ``pip install pandas``
# * Matplotlib

# %% [markdown]
# # Linking DBPedia entity types in N-gram corpus
# In this sub-tutorial, we will link DBPedia entities (and subsequently types) in an N-gram corpus. In our case, we used n-grams generated out of **Wikipedia pages**, to compare if our linking is better than original.
#
# Clone **kilogram** library if you haven't done it yet:
#
#     git clone https://github.com/dragoon/kilogram.git
#     cd kilogram/mapreduce
#
# Download required **DBPedia** datasets:
#
#     wget http://downloads.dbpedia.org/3.9/en/redirects_transitive_en.nt.bz2
#     wget http://downloads.dbpedia.org/3.9/en/instance_types_en.nt.bz2

# %%
import matplotlib.pyplot as plt
from mpltools import style
import numpy as np
style.use('ggplot')
# %matplotlib inline
import pandas as pd

# %% [markdown]
# # Original (human) linkings
# Since we want to prove we link entity types better than original (human) annonators, we need to first extract original linkings for comparison.

# %%
# Out:
# 5 sample types:
# ['Band', 'Organisation', 'Album', 'MusicalWork', 'Work']

# %% [markdown]
# # Analysis: raw counts
#
# First we try to see what happens if we perform stupid linking by means of exact string matching, using canonical and "redirect" labels of wikipedia pages. All such labels uniquely link to a single entity (ensured by wikipedia, we don't check it here).
#
# We aggregate the counts of the labels and also of their lowercase versions for further analysis.
# Initially the script will also generate DBPedia entity dictionary which maps labels to entity types (used later):
#
#     ./run_job.py -cmd "python dbpedia_dbm.py" -file "dbpedia_types.dbm" -m ./filter/mapper_lowercase.py -r ./filter/reducer_lowercase.py $NGRAM_PREFILTER_DIR $DBPEDIA_COUNT_DIR
#
# Retrieve label counts:
#
#     hdfs dfs -cat $DBPEDIA_COUNT_DIR/* > dbpedia_counts_inferred

# %%
import shelve
dbpedia_types = shelve.open('../mapreduce/dbpedia_types.dbm', flag='r')
count_dict = {}
for line in open('dbpedia_counts_inferred'):
    label, values = line.split('\t')
    upper_count, lower_count = values.split(',')
    count_dict[label] = {'new_upper': int(upper_count), 'new_lower': int(lower_count),
                       'label': label, 'orig_upper': 0, 'orig_lower': 0, 'type': dbpedia_types[label][0]}
for line in open('dbpedia_counts_original'):
    label, values = line.split('\t')
    if label in count_dict:
        upper_count, lower_count = values.split(',')
        count_dict[label].update({'orig_upper': int(upper_count), 'orig_lower': int(lower_count)})
df = pd.DataFrame(count_dict.values())
df.head()
del count_dict

# %%
print 'Total number of inferred types:',  df[(df.new_upper + df.new_lower > 0)]['type'].nunique()
print 'Total number of original types:',  df[(df.orig_upper + df.orig_lower > 0)]['type'].nunique()
# Out:
# Total number of inferred types:
# 340
# Total number of original types:
# 339

# %% [markdown]
# Let's look at first/last elements for different types, sorted by counts:

# %%
print 'Settlement type'
settl_df = df[(df.type=='Settlement')].sort('new_upper')
print settl_df[-5:].to_csv(sep='\t', index=False)
print settl_df[:5].to_csv(sep='\t', index=False)
print 'Song type'
song_df = df[(df.type=='Song')].sort('new_upper')
print song_df[-5:].to_csv(sep='\t', index=False)
print song_df[:5].to_csv(sep='\t', index=False)
# Out:
# Settlement type
# label	new_lower	new_upper	orig_lower	orig_upper	type
# Rome	15	70893	0	10	Settlement
# Boston	9	74343	0	2	Settlement
# Paris	92	120355	0	3	Settlement
# Most	977390	147258	0	106	Settlement
# York	0	396670	0	2	Settlement
# label	new_lower	new_upper	orig_lower	orig_upper	type
# Lotzen	1	0	0	0	Settlement
# Mûs	1	0	0	0	Settlement
# Tamiḻ_īḻam	1	0	0	0	Settlement
# Pailloles	2	0	0	0	Settlement
# Jeonseon	1	0	0	0	Settlement
#
# Song type
# label	new_lower	new_upper	orig_lower	orig_upper	type
# Dr._Robert	0	1076	0	2	Song
# The_Brazilian	15	1161	0	1	Song
# Yesterday	0	1312	0	1	Song
# 14_years	4329	4329	0	0	Song
# I_will	0	6061	0	0	Song
# label	new_lower	new_upper	orig_lower	orig_upper	type
# This_is_a_Low	10	0	0	0	Song
# Carry_that_Weight	3	0	0	0	Song
# Trapped_in_purgatory	3	0	0	0	Song
# Sex_101	1	0	0	1	Song
# Más_Que_Nada	1	0	0	0	Song

# %% [markdown]
# ## Inferred vs Organic counts of capitalized labels

# %%
df.plot(kind='scatter',x='orig_upper', y='new_upper', figsize=(18,10), xlim=(0,1000), ylim=(0,1000))

# %% [markdown]
# ## Inferred vs Organic counts of lowercase labels

# %%
df.plot(kind='scatter',x='orig_lower', y='new_lower', figsize=(18,10), xlim=(0,1000), ylim=(0,1000))

# %% [markdown]
# # Some corner cases

# %%
df[(df.new_upper==0) & (df.orig_upper==0)][:10]
# Out:
#      new_lower  new_upper  orig_lower  orig_upper  \
# 2            1          0           3           0
# 29           1          0           0           0
# 80           4          0           0           0
# 168         15          0           0           0
# 199          1          0           0           0
# 248          1          0           0           0
# 348          1          0           2           0
# 350          1          0           0           0
# 419          1          0           0           0
# 428          3          0           2           0
#
#                                   uri
# 2              Unadorned_rock-wallaby
# 29        Guerra_de_la_Triple_Alianza
# 80              Member_of_the_wedding
# 168                      Stink_badger
# 199            Central_lymphoid_organ
# 248         Grey-crested_Helmetshrike
# 348              Choreoacanthocytosis
# 350                      World_Runner
# 419  Cyclic_adenosine_diphosphoribose
# 428          Ubuntu-restricted-extras

# %% [markdown]
# **We never exclude the above entities - can only appear in lower case**

# %%
df[(df.new_upper>1000) & (df.orig_upper==0)][:10]
# Out:
#        new_lower  new_upper  orig_lower  orig_upper                       uri
# 3164         779       3803           1           0                     Hazel
# 8162          14       1544           2           0  National_Weather_Service
# 9971      148505     118705           3           0                     Black
# 12543          0       2141           0           0                 The_rules
# 14414       3095       2752           1           0                  Chestnut
# 14831          0       6132           0           0                  The_bill
# 23981          0       1150           0           0       American_Federation
# 27550       3410       1235           1           0                 Pathology
# 60307         63       2625           0           0         Protection_Agency
# 65600        228       1705           1           0                     Grays

# %% [markdown]
# Perhaps these cases should be filtered by new_upper/new_lower ratio

# %%
df[(df.new_lower>1000) & (df.orig_lower==0) & (df.orig_upper>0)][:10]
# Out:
#       new_lower  new_upper  orig_lower  orig_upper           uri
# 876       60981        618           0           1       Couples
# 2234       1279        170           0           2        Thrice
# 3818       3077         97           0           2     The_Cabin
# 5468       2239      42438           0           3          Ford
# 6715       2033          5           0           2         STRAP
# 7787       1784        178           0          12    The_Ladder
# 8448       7525         45           0           1         MINDS
# 9164       1857         78           0           1      Pristine
# 9293       5304         22           0           3    The_Points
# 9910       2624         26           0           1  Above_Ground

# %%
df[(df.new_lower>1000) & (df.new_upper>1000)][:10]
# Out:
#        new_lower  new_upper  orig_lower  orig_upper           uri
# 32          4138       5293           1           3          Euro
# 5468        2239      42438           0           3          Ford
# 9971      148505     118705           3           0         Black
# 12846       1045       7953           0        7485  The_Guardian
# 14414       3095       2752           1           0      Chestnut
# 23412      43721      68189           0           2         Brown
# 24087     977390     147258           0         106          Most
# 27340      20627       4755           0           3         Tours
# 27550       3410       1235           1           0     Pathology
# 30538      54292       1803           0           1        Follow

# %% [markdown]
# ## Inferred vs Organic capitalized/lowercase ratio plots

# %%
def ratio(row):
    new_ratio = row['new_upper']/float(row['new_lower'] or 1)
    orig_ratio = row['orig_upper']/float(row['orig_lower'] or 1)
    return pd.Series({'new_ratio': new_ratio, 'orig_ratio': orig_ratio, 'type': row['type']})

ratio_df = df.apply(ratio, axis=1)
print ratio_df.head()
# Out:
#    new_ratio  orig_ratio      type
# 0   6.000000           4   Station
# 1   1.000000           0  Aircraft
# 2   0.000000           0    Mammal
# 3   8.857143           3     Album
# 4  23.000000           1  Aircraft

# %%
ax=ratio_df[(ratio_df.type=='Settlement')].plot(title='Settlement type',kind='scatter',x='orig_ratio', y='new_ratio', figsize=(18,10), xlim=(0,500), ylim=(0,500))
ax=ratio_df[(ratio_df.type=='Song')].plot(title='Song type',kind='scatter',x='orig_ratio', y='new_ratio', figsize=(18,10), xlim=(0,50), ylim=(0,50))

# %%
ax=ratio_df.plot(kind='scatter',x='orig_ratio', y='new_ratio', figsize=(18,10), xlim=(0,1000), ylim=(0,1000))
x = np.arange(0, 1000, 0.1);
plt.plot(x, x, axes=ax, scaley=False, scalex=False)

# %%
from math import log
ratio_df[(ratio_df.orig_ratio<1000) & (ratio_df.new_ratio<1000)].plot(kind='hexbin', x='orig_ratio', y='new_ratio', figsize=(18,10), gridsize=50, C=1, reduce_C_function=lambda x: log(sum(x)))

# %%
# Write excludes file, create lowercase mathings file
dbpediadb_lower = {}
excludes = open('dbpedia_uri_excludes.txt', 'w')
for row in df.iterrows():
    row = row[1]
    exclude = False
    if row['orig_upper'] == 0:
        if row['new_upper'] == 0:
            pass
        else:
            new_ratio = row['new_upper']/float(row['new_lower'] or 1)
            if new_ratio < 20:
                exclude = True
    else:
        new_ratio = row['new_upper']/float(row['new_lower'] or 1)
        orig_ratio = row['orig_upper']/float(row['orig_lower'] or 1)
        if new_ratio < orig_ratio:
            exclude = True
    if exclude:
        excludes.write(row['uri']+'\n')
    elif row['orig_lower'] > 0:
        dbpediadb_lower[row['uri'].lower()] = row['uri']
excludes.close()

# %%
out = open('dbpediadb_lower.txt', 'w')
for lower_label, label in dbpediadb_lower.items():
    out.write('%s\t%s\n' % (lower_label, label))
out.close()

# %%
from collections import defaultdict
type_counts = defaultdict(lambda: [0,0])
for i, vocab in enumerate((open('dbpedia_org_types_1gms'), open('dbpedia_infer_types_1gms'))):
    for line in vocab:
        word, count = line.split('\t')
        type_counts[word][i] = int(count)
df = pd.DataFrame(sorted(type_counts.values()), columns=['orig_types', 'inferred_types'])

# %%
df.plot(kind='area', figsize=(18,10), stacked=True,)

# %%
a = open('/home/roman/berkeleylm/log_orig_types.txt')
orig_wiki_data = [float(x.split(';')[0]) for x in a]
a.close()
a = open('/home/roman/berkeleylm/log_final_types_proportional_ratio.txt')
custom_wiki_data = [float(x.split(';')[0]) for x in a]
a.close()
del custom_wiki_data[-1]
diff = [(x-y) for x,y in zip(custom_wiki_data,orig_wiki_data)]

# %%
from collections import defaultdict
type_scores = defaultdict(list)
for i, sentence in enumerate(open('/home/roman/berkeleylm/wiki_test_tokenized.txt')):
    local_types = [x for x in sentence.split() if x.startswith('<dbpedia:')]
    for t in local_types:
        type_scores[t].append(diff[i])

# %%
type_scores_mean = [(x,np.mean(y)) for x,y in type_scores.items()]
type_scores_mean.sort(key=lambda x: x[1])
type_scores_mean
# Out:
# [('<dbpedia:YearInSpaceflight>', -111.71434014285713),
#  ('<dbpedia:SnookerWorldRanking>', -104.34432224999999),
#  ('<dbpedia:MixedMartialArtsLeague>', -97.031029714285722),
#  ('<dbpedia:OlympicEvent>', -27.375093881077039),
#  ('<dbpedia:NCAATeamSeason>', -25.766124266222224),
#  ('<dbpedia:ResearchProject>', -18.760651166666666),
#  ('<dbpedia:FootballMatch>', -18.27284045467422),
#  ('<dbpedia:SoccerClubSeason>', -17.302474682409308),
#  ('<dbpedia:TennisTournament>', -16.417869154574131),
#  ('<dbpedia:SoftballLeague>', -15.512499883720933),
#  ('<dbpedia:LunarCrater>', -15.111168820790025),
#  ('<dbpedia:GrandPrix>', -15.064352094994895),
#  ('<dbpedia:NationalFootballLeagueSeason>', -14.168943583468396),
#  ('<dbpedia:OlympicResult>', -11.19556534201954),
#  ('<dbpedia:HandballLeague>', -10.684585630952377),
#  ('<dbpedia:TelevisionSeason>', -10.668920818324812),
#  ('<dbpedia:HandballPlayer>', -9.936392407407391),
#  ('<dbpedia:MotorsportSeason>', -9.2519743956262435),
#  ('<dbpedia:Election>', -8.7987807184358182),
#  ('<dbpedia:Curler>', -8.6976246401515134),
#  ('<dbpedia:PoloLeague>', -8.6379028799999986),
#  ('<dbpedia:FigureSkater>', -8.5846113959790227),
#  ('<dbpedia:SnookerChamp>', -7.9821451006711426),
#  ('<dbpedia:Bird>', -7.9518076918096394),
#  ('<dbpedia:CanadianFootballLeague>', -7.6186762701298729),
#  ('<dbpedia:Swimmer>', -7.4852809513618634),
#  ('<dbpedia:TennisPlayer>', -6.8827992602021721),
#  ('<dbpedia:RugbyClub>', -6.7681752478421702),
#  ('<dbpedia:FootballLeagueSeason>', -6.7388902617737001),
#  ('<dbpedia:SnookerPlayer>', -6.3354627385892117),
#  ('<dbpedia:Moss>', -6.3203504077380952),
#  ('<dbpedia:SportsTeamMember>', -6.1439991731843584),
#  ('<dbpedia:Mollusca>', -6.0274909574666271),
#  ('<dbpedia:Sport>', -5.8885968788785981),
#  ('<dbpedia:Mammal>', -5.8239986136284143),
#  ('<dbpedia:Comedian>', -5.7853160635728837),
#  ('<dbpedia:LaunchPad>', -5.7370878016304356),
#  ('<dbpedia:SupremeCourtOfTheUnitedStatesCase>', -5.4469045670289855),
#  ('<dbpedia:Ship>', -5.396014983755177),
#  ('<dbpedia:SpaceShuttle>', -5.2749512946428565),
#  ('<dbpedia:InlineHockeyLeague>', -5.1591982454545464),
#  ('<dbpedia:GolfPlayer>', -5.1474543560709396),
#  ('<dbpedia:Model>', -5.0226081011470294),
#  ('<dbpedia:LacrosseLeague>', -5.0185446764705883),
#  ('<dbpedia:Cricketer>', -4.9305762922395919),
#  ('<dbpedia:FashionDesigner>', -4.8251666591154256),
#  ('<dbpedia:RugbyPlayer>', -4.7121142463792234),
#  ('<dbpedia:Musical>', -4.6909393788372098),
#  ('<dbpedia:FormulaOneRacer>', -4.629159374593339),
#  ('<dbpedia:Band>', -4.6229510570423908),
#  ('<dbpedia:TelevisionEpisode>', -4.6156073107421216),
#  ('<dbpedia:Insect>', -4.5712768101157133),
#  ('<dbpedia:TennisLeague>', -4.5542991781914903),
#  ('<dbpedia:VideogamesLeague>', -4.5041594081632574),
#  ('<dbpedia:Fern>', -4.5010478431372549),
#  ('<dbpedia:ChessPlayer>', -4.4582676100433973),
#  ('<dbpedia:Film>', -4.4040611029724834),
#  ('<dbpedia:VolleyballLeague>', -4.3295831382978749),
#  ('<dbpedia:Locomotive>', -4.3279789480659989),
#  ('<dbpedia:FieldHockeyLeague>', -4.2577495666666652),
#  ('<dbpedia:Amphibian>', -4.2439521866938215),
#  ('<dbpedia:Station>', -4.2346034310116334),
#  ('<dbpedia:Skyscraper>', -4.2127069999999662),
#  ('<dbpedia:Fish>', -4.1871988670876323),
#  ('<dbpedia:College>', -4.1270309757412402),
#  ('<dbpedia:EurovisionSongContestEntry>', -4.1249318486111113),
#  ('<dbpedia:WineRegion>', -4.1094319463955644),
#  ('<dbpedia:Archaea>', -4.0175138557692334),
#  ('<dbpedia:ComicsCreator>', -4.0142039859872609),
#  ('<dbpedia:AustralianRulesFootballPlayer>', -3.9907839580230209),
#  ('<dbpedia:ArtistDiscography>', -3.9816641092436997),
#  ('<dbpedia:Gnetophytes>', -3.9585635714285803),
#  ('<dbpedia:Single>', -3.9092758891410786),
#  ('<dbpedia:Diocese>', -3.8256334417246802),
#  ('<dbpedia:AdultActor>', -3.8039310172872343),
#  ('<dbpedia:WomensTennisAssociationTournament>', -3.7699850689655201),
#  ('<dbpedia:AmericanFootballPlayer>', -3.7663231624075495),
#  ('<dbpedia:Play>', -3.7222417645958079),
#  ('<dbpedia:SoccerPlayer>', -3.719611276043453),
#  ('<dbpedia:SoccerManager>', -3.6779348867323289),
#  ('<dbpedia:SumoWrestler>', -3.6272772779661038),
#  ('<dbpedia:Senator>', -3.6214193344523711),
#  ('<dbpedia:Artist>', -3.5955289756002595),
#  ('<dbpedia:BaseballPlayer>', -3.5515113010979977),
#  ('<dbpedia:Cycad>', -3.5409794891304327),
#  ('<dbpedia:MusicalArtist>', -3.5381583411905324),
#  ('<dbpedia:MusicGenre>', -3.5312618884655347),
#  ('<dbpedia:Congressman>', -3.4286274491255964),
#  ('<dbpedia:Person>', -3.424605889704301),
#  ('<dbpedia:Skater>', -3.4191315037594014),
#  ('<dbpedia:SquashPlayer>', -3.384312563636362),
#  ('<dbpedia:Ambassador>', -3.368306306930692),
#  ('<dbpedia:CanadianFootballTeam>', -3.3470635968253966),
#  ('<dbpedia:School>', -3.3418269183435179),
#  ('<dbpedia:GridironFootballPlayer>', -3.3208568895934354),
#  ('<dbpedia:BasketballPlayer>', -3.31632816464806),
#  ('<dbpedia:MotorcycleRider>', -3.3105506258333341),
#  ('<dbpedia:Actor>', -3.2991796730835334),
#  ('<dbpedia:Train>', -3.2059495447619044),
#  ('<dbpedia:Bacteria>', -3.198322292490118),
#  ('<dbpedia:Cyclist>', -3.1959533630534356),
#  ('<dbpedia:SoapCharacter>', -3.1619360513965051),
#  ('<dbpedia:Song>', -3.1370446227002549),
#  ('<dbpedia:Fungus>', -3.1074448284473406),
#  ('<dbpedia:PoliticalParty>', -3.1015045841149811),
#  ('<dbpedia:Skier>', -3.090818834782608),
#  ('<dbpedia:LacrossePlayer>', -3.0894443013698574),
#  ('<dbpedia:TradeUnion>', -3.0693134724680431),
#  ('<dbpedia:IceHockeyPlayer>', -3.0571138570297665),
#  ('<dbpedia:RadioHost>', -3.0495900130890052),
#  ('<dbpedia:TelevisionShow>', -3.048232884385107),
#  ('<dbpedia:SoccerClub>', -3.0458597641304763),
#  ('<dbpedia:Economist>', -3.0199699777676954),
#  ('<dbpedia:Colour>', -3.0199100155728589),
#  ('<dbpedia:WrittenWork>', -2.9872567373134338),
#  ('<dbpedia:IceHockeyLeague>', -2.9830487209821421),
#  ('<dbpedia:PlayboyPlaymate>', -2.9711773749999977),
#  ('<dbpedia:NationalCollegiateAthleticAssociationAthlete>',
#   -2.9372588789473699),
#  ('<dbpedia:FilmFestival>', -2.9086286174593972),
#  ('<dbpedia:FloweringPlant>', -2.8562940489776509),
#  ('<dbpedia:CultivatedVariety>', -2.8496362989214177),
#  ('<dbpedia:RailwayStation>', -2.8244220924657539),
#  ('<dbpedia:MemberOfParliament>', -2.8177024263877715),
#  ('<dbpedia:AutoRacingLeague>', -2.8104015952380954),
#  ('<dbpedia:NascarDriver>', -2.8009485943060506),
#  ('<dbpedia:Noble>', -2.7919645305393495),
#  ('<dbpedia:SkiArea>', -2.7806494627831735),
#  ('<dbpedia:Museum>', -2.7380561875351273),
#  ('<dbpedia:RailwayLine>', -2.7320600247810138),
#  ('<dbpedia:Album>', -2.7255005836379533),
#  ('<dbpedia:Reptile>', -2.7009435796255281),
#  ('<dbpedia:BadmintonPlayer>', -2.6877828133333335),
#  ('<dbpedia:RadioProgram>', -2.6495798238074788),
#  ('<dbpedia:Mineral>', -2.6447506981674453),
#  ('<dbpedia:Judge>', -2.6301738018628287),
#  ('<dbpedia:SpeedwayRider>', -2.6005604387351746),
#  ('<dbpedia:ProgrammingLanguage>', -2.5776430808408821),
#  ('<dbpedia:SpeedwayTeam>', -2.5750237043478243),
#  ('<dbpedia:RacingDriver>', -2.5617370546204046),
#  ('<dbpedia:Planet>', -2.5203237888904275),
#  ('<dbpedia:Athlete>', -2.4877140657142847),
#  ('<dbpedia:Writer>', -2.4691508349782616),
#  ('<dbpedia:Conifer>', -2.4514545670553933),
#  ('<dbpedia:Plant>', -2.4363770331875991),
#  ('<dbpedia:RaceHorse>', -2.4031525640845071),
#  ('<dbpedia:Tunnel>', -2.3748434814814789),
#  ('<dbpedia:CollegeCoach>', -2.3589157995457128),
#  ('<dbpedia:Artwork>', -2.3458627223393047),
#  ('<dbpedia:Language>', -2.3127357799563542),
#  ('<dbpedia:Ligament>', -2.2830337096774178),
#  ('<dbpedia:Olympics>', -2.269028570544767),
#  ('<dbpedia:GaelicGamesPlayer>', -2.2292847090119436),
#  ('<dbpedia:Bodybuilder>', -2.2268551190476171),
#  ('<dbpedia:MusicFestival>', -2.2171006762500003),
#  ('<dbpedia:Chef>', -2.1729536861598455),
#  ('<dbpedia:SoccerLeague>', -2.1504435814993954),
#  ('<dbpedia:Medician>', -2.1124385505882346),
#  ('<dbpedia:Legislature>', -2.0976579887927693),
#  ('<dbpedia:GovernmentAgency>', -2.0683135825211738),
#  ('<dbpedia:Racecourse>', -2.0639761553123903),
#  ('<dbpedia:ClubMoss>', -2.048900831168833),
#  ('<dbpedia:Wrestler>', -2.0359433953859138),
#  ('<dbpedia:Gymnast>', -2.0229504027777745),
#  ('<dbpedia:HockeyTeam>', -2.0058530277108431),
#  ('<dbpedia:WrestlingEvent>', -1.9659637840909081),
#  ('<dbpedia:Award>', -1.9646818793466325),
#  ('<dbpedia:ComedyGroup>', -1.9604598393574302),
#  ('<dbpedia:BasketballLeague>', -1.9444963181574724),
#  ('<dbpedia:ProtectedArea>', -1.9402379709396667),
#  ('<dbpedia:Village>', -1.9372959502848519),
#  ('<dbpedia:Website>', -1.9370532478235938),
#  ('<dbpedia:BeautyQueen>', -1.9233875249457697),
#  ('<dbpedia:ReligiousBuilding>', -1.9224022844421158),
#  ('<dbpedia:Boxer>', -1.9158466646039605),
#  ('<dbpedia:HistoricBuilding>', -1.9089664363865679),
#  ('<dbpedia:Book>', -1.8765002342630073),
#  ('<dbpedia:CyclingTeam>', -1.8648365168539343),
#  ('<dbpedia:BasketballTeam>', -1.8511428242640493),
#  ('<dbpedia:Crustacean>', -1.8424291616161614),
#  ('<dbpedia:Mayor>', -1.8301710326340319),
#  ('<dbpedia:Chancellor>', -1.7887627836257298),
#  ('<dbpedia:Theatre>', -1.7659563574971384),
#  ('<dbpedia:AutomobileEngine>', -1.7613366825969352),
#  ('<dbpedia:PrimeMinister>', -1.7575304221355568),
#  ('<dbpedia:LawFirm>', -1.7493691513157914),
#  ('<dbpedia:Politician>', -1.7397642741808357),
#  ('<dbpedia:NetballPlayer>', -1.7164132638888883),
#  ('<dbpedia:FictionalCharacter>', -1.7151747849476731),
#  ('<dbpedia:Muscle>', -1.7107818051738082),
#  ('<dbpedia:Currency>', -1.7079249358407083),
#  ('<dbpedia:Presenter>', -1.7045876769230761),
#  ('<dbpedia:PublicTransitSystem>', -1.7016106478473834),
#  ('<dbpedia:Airport>', -1.6721546089959054),
#  ('<dbpedia:MilitaryConflict>', -1.6639050421370662),
#  ('<dbpedia:TelevisionHost>', -1.6577867482014368),
#  ('<dbpedia:MartialArtist>', -1.6500268982645128),
#  ('<dbpedia:PowerStation>', -1.6496395114259597),
#  ('<dbpedia:OfficeHolder>', -1.631701304992758),
#  ('<dbpedia:Library>', -1.6303250540448675),
#  ('<dbpedia:Architect>', -1.6278322951838426),
#  ('<dbpedia:Philosopher>', -1.6214123746894737),
#  ('<dbpedia:RailwayTunnel>', -1.5980869161676643),
#  ('<dbpedia:MilitaryStructure>', -1.5950995662441143),
#  ('<dbpedia:Governor>', -1.5950925452312137),
#  ('<dbpedia:Eukaryote>', -1.5803224113660066),
#  ('<dbpedia:Scientist>', -1.5772089776147753),
#  ('<dbpedia:AcademicJournal>', -1.564373519411987),
#  ('<dbpedia:MilitaryPerson>', -1.5570772686117518),
#  ('<dbpedia:Embryology>', -1.554284504410584),
#  ('<dbpedia:Comics>', -1.5450822916188294),
#  ('<dbpedia:Weapon>', -1.5215557885393105),
#  ('<dbpedia:RecordLabel>', -1.5193231381310612),
#  ('<dbpedia:SportsTeam>', -1.518990307624114),
#  ('<dbpedia:RugbyLeague>', -1.5171042972258915),
#  ('<dbpedia:GolfLeague>', -1.5159992807017539),
#  ('<dbpedia:Engineer>', -1.508566630479103),
#  ('<dbpedia:Stadium>', -1.5070330319079377),
#  ('<dbpedia:TableTennisPlayer>', -1.4901169315068485),
#  ('<dbpedia:Hospital>', -1.4821342179132044),
#  ('<dbpedia:Volcano>', -1.4691420015957448),
#  ('<dbpedia:Magazine>', -1.4636457288477764),
#  ('<dbpedia:VolleyballCoach>', -1.4534606250000088),
#  ('<dbpedia:PokerPlayer>', -1.4315811333333348),
#  ('<dbpedia:DartsPlayer>', -1.4241103343373493),
#  ('<dbpedia:GreenAlga>', -1.4226728141592921),
#  ('<dbpedia:BritishRoyalty>', -1.4151954221198846),
#  ('<dbpedia:Lymph>', -1.3818208955223887),
#  ('<dbpedia:Astronaut>', -1.3762801894005214),
#  ('<dbpedia:Organisation>', -1.3557184841371486),
#  ('<dbpedia:Beverage>', -1.3479770789223455),
#  ('<dbpedia:HollywoodCartoon>', -1.329347337125131),
#  ('<dbpedia:SpeedwayLeague>', -1.3266567555555557),
#  ('<dbpedia:University>', -1.3158772280298683),
#  ('<dbpedia:RoadJunction>', -1.3144781104972398),
#  ('<dbpedia:Town>', -1.3075083173594477),
#  ('<dbpedia:HorseTrainer>', -1.2877475300859609),
#  ('<dbpedia:AmericanFootballLeague>', -1.2857935381691479),
#  ('<dbpedia:Jockey>', -1.2426903404669263),
#  ('<dbpedia:MilitaryUnit>', -1.2413290532645871),
#  ('<dbpedia:President>', -1.2304700644257704),
#  ('<dbpedia:Arachnid>', -1.214725235426009),
#  ('<dbpedia:Road>', -1.2123875364916121),
#  ('<dbpedia:Brain>', -1.2052079659659656),
#  ('<dbpedia:SpaceStation>', -1.1899346680216802),
#  ('<dbpedia:Venue>', -1.1839615184021548),
#  ('<dbpedia:Non-ProfitOrganisation>', -1.1744470323765022),
#  ('<dbpedia:Device>', -1.165550951557093),
#  ('<dbpedia:ComicsCharacter>', -1.1324780483981185),
#  ('<dbpedia:Lighthouse>', -1.1281067047496804),
#  ('<dbpedia:Automobile>', -1.1208165252303861),
#  ('<dbpedia:MixedMartialArtsEvent>', -1.11293228104575),
#  ('<dbpedia:BroadcastNetwork>', -1.1063061135170602),
#  ('<dbpedia:RadioStation>', -1.099652372174855),
#  ('<dbpedia:HistoricPlace>', -1.096838755189609),
#  ('<dbpedia:Artery>', -1.0922461409090904),
#  ('<dbpedia:Nerve>', -1.0895197432905495),
#  ('<dbpedia:Monument>', -1.0786710334346512),
#  ('<dbpedia:Drug>', -1.0692185306685593),
#  ('<dbpedia:ShoppingMall>', -1.0523190503273316),
#  ('<dbpedia:MotorcycleRacingLeague>', -1.047186738095234),
#  ('<dbpedia:Building>', -1.0284622891315651),
#  ('<dbpedia:Aircraft>', -1.0185392088393255),
#  ('<dbpedia:BaseballLeague>', -1.0177954146645307),
#  ('<dbpedia:Bone>', -1.0165046671755718),
#  ('<dbpedia:Disease>', -1.0146300346757677),
#  ('<dbpedia:Grape>', -0.99895399847094857),
#  ('<dbpedia:BeachVolleyballPlayer>', -0.98312949999999333),
#  ('<dbpedia:Spacecraft>', -0.97676912121212056),
#  ('<dbpedia:Animal>', -0.96444403324867256),
#  ('<dbpedia:ChemicalCompound>', -0.96110316287191899),
#  ('<dbpedia:Cardinal>', -0.95450728019323761),
#  ('<dbpedia:Anime>', -0.93829375852782637),
#  ('<dbpedia:Rocket>', -0.92702098756084383),
#  ('<dbpedia:Software>', -0.91360638998060539),
#  ('<dbpedia:Journalist>', -0.90069387500000175),
#  ('<dbpedia:Food>', -0.8830844111586108),
#  ('<dbpedia:Newspaper>', -0.88109811957419204),
#  ('<dbpedia:TelevisionStation>', -0.86607728388346183),
#  ('<dbpedia:Airline>', -0.85861007215917085),
#  ('<dbpedia:Prison>', -0.85679505178979465),
#  ('<dbpedia:Species>', -0.83136335032493869),
#  ('<dbpedia:Castle>', -0.82623849557522233),
#  ('<dbpedia:WaterwayTunnel>', -0.80239827999999425),
#  ('<dbpedia:Bridge>', -0.79983965878813923),
#  ('<dbpedia:Restaurant>', -0.79593024905660414),
#  ('<dbpedia:Company>', -0.78478475525662084),
#  ('<dbpedia:VideoGame>', -0.78431105753098795),
#  ('<dbpedia:Publisher>', -0.77775779342250873),
#  ('<dbpedia:Vein>', -0.74353405523255889),
#  ('<dbpedia:AdministrativeRegion>', -0.71781727273675688),
#  ('<dbpedia:Settlement>', -0.71768303712680748),
#  ('<dbpedia:Criminal>', -0.71250240866987802),
#  ('<dbpedia:ChristianBishop>', -0.7017236496712731),
#  ('<dbpedia:Park>', -0.6945107624145106),
#  ('<dbpedia:Hotel>', -0.68678689056225051),
#  ('<dbpedia:InformationAppliance>', -0.66559101978501312),
#  ('<dbpedia:Convention>', -0.66469766761565807),
#  ('<dbpedia:Manga>', -0.64103093608652884),
#  ('<dbpedia:AmateurBoxer>', -0.63536370588235092),
#  ('<dbpedia:Protein>', -0.60349053123185414),
#  ('<dbpedia:RoadTunnel>', -0.588494385892116),
#  ('<dbpedia:SiteOfSpecialScientificInterest>', -0.58181318012422201),
#  ('<dbpedia:SpaceMission>', -0.57091989115168529),
#  ('<dbpedia:Enzyme>', -0.55709189722675412),
#  ('<dbpedia:AnatomicalStructure>', -0.55029284690878022),
#  ('<dbpedia:Mountain>', -0.43972779457046551),
#  ('<dbpedia:Cave>', -0.38424304901960754),
#  ('<dbpedia:Murderer>', -0.38035430210016108),
#  ('<dbpedia:SportsLeague>', -0.34782083123612145),
#  ('<dbpedia:EthnicGroup>', -0.34738679568871289),
#  ('<dbpedia:City>', -0.33023973628769399),
#  ('<dbpedia:Monarch>', -0.29702093763362036),
#  ('<dbpedia:Canal>', -0.28051865753424604),
#  ('<dbpedia:AmericanFootballTeam>', -0.28001820043811515),
#  ('<dbpedia:Saint>', -0.27724931169119282),
#  ('<dbpedia:Place>', -0.2643989722863741),
#  ('<dbpedia:Valley>', -0.25674347783251211),
#  ('<dbpedia:Star>', -0.25397281161007712),
#  ('<dbpedia:Game>', -0.25182019654231136),
#  ('<dbpedia:WorldHeritageSite>', -0.24762952201676219),
#  ('<dbpedia:River>', -0.24094016513395486),
#  ('<dbpedia:MountainRange>', -0.20542500197238678),
#  ('<dbpedia:Lake>', -0.18808351333051226),
#  ('<dbpedia:Island>', -0.13951723171407474),
#  ('<dbpedia:Race>', -0.12559364713217144),
#  ('<dbpedia:Galaxy>', -0.0096026301369896028),
#  ('<dbpedia:Country>', -0.0057563887374390034),
#  ('<dbpedia:BiologicalDatabase>', 0.0078138581818238476),
#  ('<dbpedia:VolleyballPlayer>', 0.025386821428570881),
#  ('<dbpedia:AnimangaCharacter>', 0.19863543469387857),
#  ('<dbpedia:Holiday>', 0.50676006405408514),
#  ('<dbpedia:Religious>', 0.51641007534573291),
#  ('<dbpedia:BodyOfWater>', 0.51876428985507039),
#  ('<dbpedia:Stream>', 0.85374071428571185),
#  ('<dbpedia:Continent>', 1.0812008104372934),
#  ('<dbpedia:CricketLeague>', 1.7341562499999992),
#  ('<dbpedia:GivenName>', 1.8104798427906976),
#  ('<dbpedia:AustralianFootballLeague>', 3.3167917500000073),
#  ('<dbpedia:Ginkgo>', 5.8991193333333269)]

# %%
df = pd.DataFrame(diff)
df.hist(bins=300, figsize=(18,10), log=True)
print df.mean()
print df.std()
# Out:
# 0   -0.28304
# dtype: float64
# 0    1.780638
# dtype: float64

# %%
diff_index = list(enumerate(diff))

# %%
diff_index = sorted(diff_index, key=lambda x: x[1], reverse=True)

# %%
print diff_index[:10]
print diff_index[-10:]
# Out:
# [(11689959, 157.20396399999998), (6657188, 84.78430200000003), (5766879, 78.90405299999975), (5945223, 60.64941399999998), (5202830, 59.59139999999999), (172833, 56.64935300000002), (2249294, 56.38552800000002), (2218153, 48.81777999999997), (2996767, 48.74472000000003), (6493738, 45.85272299999997)]
# [(12119877, -137.380859), (6517039, -139.410752), (6124988, -142.230163), (5111928, -142.7885739999997), (11189238, -146.905579), (11630025, -149.415222), (4323770, -151.47583000000003), (700614, -166.67001299999998), (4026111, -178.67459099999996), (11018117, -180.33813500000002)]

# %%
print sum(custom_wiki_data)/274831133
print sum(orig_wiki_data)/274831133
# Out:
# -10.2738133559
# -10.2612970373

# %% [markdown]
# Run a job to generate typed n-grams for non-excluded entities: (we have also added the "excludes file" to the repo):
#
#     ./run_job.py -file "dbpedia_types.dbm" "../extra/dbpedia_uri_excludes.txt" "../extra/dbpediadb_lower.txt" -m ./filter/mapper_dbpedia.py $NGRAM_PREFILTER_DIR $DBPEDIA_TYPE_DIR
#
# Then move typed n-grams back to $NGRAM_PREFILTER_DIR (with different names, we move it to save time instead of running a merge job):
#
#     ./move_plain.sh
